# %% [markdown]
# ## 1. Comparación de algoritmos

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./comparasion_algoritmos.csv')
df
# Out:
#            dataset  algoritmo1  algoritmo2
# 0        City-Temp       24.17       22.92
# 1        Stocks-UK       21.51       16.70
# 2       Stocks-USA       19.22       12.06
# 3        Stocks-DE       20.78       13.46
# 4      IR-bio-temp       22.90       18.94
# 5         Wind-dir       28.15       19.80
# 6        PM10-dust       19.92       13.68
# 7   Dew-Point-Temp       39.03       32.49
# 8     Air-Pressure       27.89       19.23
# 9       Basel-wind       48.87       45.65
# 10      Basel-temp       36.51       30.12
# 11   Bitcoin-price       57.08       47.17
# 12  Bird-migration       35.94       28.37
# 13      Air-sensor       63.43       49.56
# 14     Food-prices       28.31       24.59
# 15         POI-lat       71.73       47.71
# 16        POI-Llon       75.89       54.55
# 17   Blockchain-tr       62.60       53.16
# 18        SD-bench       23.04       17.00

# %%
# Hacer que los datasets aparezcan en el eje x
df.set_index('dataset', inplace=True)
df
# Out:
#                 algoritmo1  algoritmo2
# dataset
# City-Temp            24.17       22.92
# Stocks-UK            21.51       16.70
# Stocks-USA           19.22       12.06
# Stocks-DE            20.78       13.46
# IR-bio-temp          22.90       18.94
# Wind-dir             28.15       19.80
# PM10-dust            19.92       13.68
# Dew-Point-Temp       39.03       32.49
# Air-Pressure         27.89       19.23
# Basel-wind           48.87       45.65
# Basel-temp           36.51       30.12
# Bitcoin-price        57.08       47.17
# Bird-migration       35.94       28.37
# Air-sensor           63.43       49.56
# Food-prices          28.31       24.59
# POI-lat              71.73       47.71
# POI-Llon             75.89       54.55
# Blockchain-tr        62.60       53.16
# SD-bench             23.04       17.00

# %%
# Creamos el gráfico de barras
grafico = df.plot.bar(
    width=0.6,                     
    figsize=(12, 6),              
    title='Evaluación de Algoritmo1 vs Algoritmo2',  
    grid=True,                    
    legend=True,                   
    ylabel='Rendimiento',         
    rot=90,                       
)
plt.show()

# %% [markdown]
# ## 2. Comparación de categorías

# %%
df2 = pd.read_csv('./datasets_top_4.csv')
df2
# Out:
#                    dataset       cat1       cat2       cat3      otros
# 0                   arade4  49.759495  20.770575   6.280610  23.189320
# 1             basel_temp_f  73.695473  22.569984   0.291341   3.443202
# 2             basel_wind_f  67.390949  24.599608   2.985026   5.024417
# 3         bird_migration_f  44.973576  28.504147  13.051469  13.470807
# 4                bitcoin_f  68.701150   7.519535   1.025393  22.753922
# 5   bitcoin_transactions_f  59.006077  10.651040   7.901476  22.441407
# 6       city_temperature_f  55.766159  18.470318  15.352960  10.410563
# 7                     cms1  50.301599  11.414799   4.405325  33.878277
# 8                    cms25   8.793950   3.629491   1.931263  85.645296
# 9                     cms9  99.889249   0.073619   0.017582   0.019549
# 10             food_prices  63.307736  17.856899   8.406486  10.428878
# 11                   gov10  60.208603  25.086608   7.214388   7.490400
# ...

# %%
# Dividir el DataFrame en dos partes
n = len(df2) // 2
df2_parte1 = df2.iloc[:n]
df2_parte2 = df2.iloc[n:]

# %%
import matplotlib.patches as mpatches

# %%
# Crear una figura y dos subgráficos con tamaño ajustado
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Crear el primer gráfico
df2_parte1.plot.barh(
    stacked=True,                      
    color=['#000086', '#5396F4', '#A1DBE8', '#DADADA'], 
    xlabel='Porcentaje',
    ylabel='Dataset',
    ax=ax1  
)

# Configurar los nombres de los datasets en el eje y para la parte 1
ax1.set_yticklabels(df2_parte1['dataset'])

# Crear el segundo gráfico de barras apiladas horizontalmente en el segundo subgráfico
df2_parte2.plot.barh(
    stacked=True,                     
    color=['#000086', '#5396F4', '#A1DBE8', '#DADADA'], 
    xlabel='Porcentaje',
    ax=ax2 
)

# Configurar los nombres de los datasets en el eje y para la parte 2
ax2.set_yticklabels(df2_parte2['dataset'])

# Eliminar la leyenda de colores de cada subgráfico individual
ax1.get_legend().remove()
ax2.get_legend().remove()

# Crear una leyenda personalizada para los colores de las categorías en la figura
legend_labels = ['Categoría1', 'Categoría2', 'Categoría3', 'Otros']
legend_colors = ['#000086', '#5396F4', '#A1DBE8', '#DADADA']
legend_patches = [mpatches.Patch(color=color, label=label) for color, label in zip(legend_colors, legend_labels)]

fig.legend(handles=legend_patches, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=4)

fig.suptitle('Distribucion de los datasets', fontsize=16)

# Posicionar los nombres de los datasets a la derecha en el gráfico de la derecha
ax2.yaxis.tick_right()

# Mostrar la figura con ambos subgráficos y la leyenda
plt.show()

# %% [markdown]
# ## 3. Surfistas

# %%
# Cargar los datos
dataSurf = pd.read_csv('viajes_surfistas.csv')
dataSurf
# Out:
#                            homename  homecontinent               homecountry  \
# 0            Canadian in La La Land  North America  United States of America
# 1            Canadian in La La Land  North America  United States of America
# 2            Canadian in La La Land  North America  United States of America
# 3            Canadian in La La Land  North America  United States of America
# 4            Canadian in La La Land  North America  United States of America
# ...                             ...            ...                       ...
# 9506  Bridgetown, Western Australia      Australia                 Australia
# 9507                  Lille, France         Europe                    France
# 9508                             MX  South America                    Mexico
# 9509        Kuta - Bali - Indonesia           Asia                 Indonesia
# 9510        Kuta - Bali - Indonesia           Asia                 Indonesia
#
# ...

# %%
# Contar el número de surfistas por país de procedencia
surfistas_por_pais = dataSurf['homecountry'].value_counts()
surfistas_por_pais
# Out:
# homecountry
# United States of America    2826
# Japan                        893
# Australia                    809
# Spain                        752
# United Kingdom               496
#                             ...
# Grenada                        1
# Kenya                          1
# Fiji                           1
# Pakistan                       1
# Andorra                        1
# Name: count, Length: 101, dtype: int64

# %%
# Calcular el porcentaje de surfistas por país
porcentaje_surfistas_por_pais = (surfistas_por_pais / surfistas_por_pais.sum()) * 100
porcentaje_surfistas_por_pais
# Out:
# homecountry
# United States of America    29.712964
# Japan                        9.389128
# Australia                    8.505940
# Spain                        7.906634
# United Kingdom               5.215014
#                               ...
# Grenada                      0.010514
# Kenya                        0.010514
# Fiji                         0.010514
# Pakistan                     0.010514
# Andorra                      0.010514
# Name: count, Length: 101, dtype: float64

# %%
# Seleccionar los cuatro países con los porcentajes más altos
top_paises = porcentaje_surfistas_por_pais.nlargest(4)
top_paises
# Out:
# homecountry
# United States of America    29.712964
# Japan                        9.389128
# Australia                    8.505940
# Spain                        7.906634
# Name: count, dtype: float64

# %%
# Calcular la suma de los porcentajes de los demás países
otros_paises = porcentaje_surfistas_por_pais.drop(top_paises.index).sum()
otros_paises
# Out:
# 44.48533277257911

# %%
# Resetear el índice del DataFrame
otros_serie = pd.Series({ 'Otros': otros_paises })
otros_serie
# Out:
# Otros    44.485333
# dtype: float64

# %%
# Eliminar la columna 'count'
catFinales = pd.concat([top_paises, otros_serie], axis=0)
catFinales
# Out:
# United States of America    29.712964
# Japan                        9.389128
# Australia                    8.505940
# Spain                        7.906634
# Otros                       44.485333
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Lista de colores personalizados
colores_personalizados = ['#A1DBE8', '#CCEBC5', '#FED9A6', '#E5D8BD', '#F2F2F2']

# Crear un gráfico de tarta con colores personalizados
catFinales.plot.pie(autopct='%1.1f%%',
                    figsize=(10, 6),
                    legend=True,
                    startangle=90,
                    colors=colores_personalizados,
                    fontsize='13',
                   )

# Ajustar el tamaño de la letra del título
plt.title('Porcentaje de Surfistas por País de Procedencia', fontsize='17')

# Ajustar la posición de la leyenda y cambiar su título y tamaño de fuente
plt.legend(title="Pais de Surfistas", loc="upper right", title_fontsize='13', bbox_to_anchor=(1.5, 1))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 4. Ventas

# %%
dataVentas = pd.read_csv('tienda_ventas.csv')
dataVentas
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 2161561  2161561  2016-04-30          9                     POULTRY
# 2161562  2161562  2016-04-30          9              PREPARED FOODS
# 2161563  2161563  2016-04-30          9                     PRODUCE
# 2161564  2161564  2016-04-30          9  SCHOOL AND OFFICE SUPPLIES
# 2161565  2161565  2016-04-30          9                     SEAFOOD
#
#               sales  onpromotion
# 0           0.00000            0
# 1           0.00000            0
# 2           0.00000            0
# ...

# %%
# Obtener las 5 tiendas (family) con la suma más alta de ventas
top_families = dataVentas.groupby('family')['sales'].sum().nlargest(5).index
top_families
# Out:
# Index(['GROCERY I', 'BEVERAGES', 'CLEANING', 'PRODUCE', 'DAIRY'], dtype='object', name='family')

# %%
# Convertir la columna 'date' a tipo datetime para agrupar por mes
dataVentas['date'] = pd.to_datetime(dataVentas['date'])

# Agregar una columna para el mes y el año
dataVentas['year_month'] = dataVentas['date'].dt.to_period('M')

# Filtrar las ventas solo de las 5 tiendas principales
dataVentas_top_families = dataVentas[dataVentas['family'].isin(top_families)]
dataVentas_top_families
# Out:
#               id       date  store_nbr     family      sales  onpromotion  \
# 3              3 2013-01-01          1  BEVERAGES      0.000            0
# 7              7 2013-01-01          1   CLEANING      0.000            0
# 8              8 2013-01-01          1      DAIRY      0.000            0
# 12            12 2013-01-01          1  GROCERY I      0.000            0
# 30            30 2013-01-01          1    PRODUCE      0.000            0
# ...          ...        ...        ...        ...        ...          ...
# 2161536  2161536 2016-04-30          9  BEVERAGES   5786.000           33
# 2161540  2161540 2016-04-30          9   CLEANING   2910.000           11
# 2161541  2161541 2016-04-30          9      DAIRY   1351.000           11
# 2161545  2161545 2016-04-30          9  GROCERY I  11326.015           56
# 2161563  2161563 2016-04-30          9    PRODUCE   2012.727            1
#
#         year_month
# 3          2013-01
# 7          2013-01
# ...

# %%
# Agrupar y sumar las ventas por tienda en intervalos de 1 mes
ventas_mensuales = dataVentas_top_families.groupby(['family', 'year_month'])['sales'].sum().reset_index()

# Convertir 'year_month' a una fecha de tipo datetime para la gráfica
ventas_mensuales['year_month'] = ventas_mensuales['year_month'].dt.to_timestamp()
ventas_mensuales
# Out:
#         family year_month         sales
# 0    BEVERAGES 2013-01-01  1.670653e+06
# 1    BEVERAGES 2013-02-01  1.508254e+06
# 2    BEVERAGES 2013-03-01  1.822220e+06
# 3    BEVERAGES 2013-04-01  1.743121e+06
# 4    BEVERAGES 2013-05-01  1.824123e+06
# ..         ...        ...           ...
# 195    PRODUCE 2015-12-01  4.052565e+06
# 196    PRODUCE 2016-01-01  3.980592e+06
# 197    PRODUCE 2016-02-01  3.585009e+06
# 198    PRODUCE 2016-03-01  3.786813e+06
# 199    PRODUCE 2016-04-01  3.621327e+06
#
# [200 rows x 3 columns]

# %%
# Crear la gráfica de líneas
plt.figure(figsize=(14, 7))

for family in top_families:
    family_data = ventas_mensuales[ventas_mensuales['family'] == family]
    plt.plot(family_data['year_month'], family_data['sales'], label=family)

plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.title('Ventas mensuales por tienda')
plt.legend(title='Family')
plt.grid(True)
plt.show()
